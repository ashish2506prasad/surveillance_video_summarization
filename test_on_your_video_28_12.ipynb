# %%
! git clone https://github.com/showlab/UniVTG
! cd UniVTG && pip install -r requirements.txt
# Out:
# fatal: destination path 'UniVTG' already exists and is not an empty directory.
# ...
#   Using cached absl_py-1.2.0-py3-none-any.whl (123 kB)
# ...
#   Using cached accelerate-0.19.0-py3-none-any.whl (219 kB)
# ...
#   Using cached aiodns-3.0.0-py3-none-any.whl (5.0 kB)
# ...
#   Using cached aiofiles-23.1.0-py3-none-any.whl (14 kB)
# ...
#   Using cached aiohttp-3.8.3-cp311-cp311-win_amd64.whl (317 kB)
# ...
#   Using cached aiohttp_socks-0.7.1-py3-none-any.whl (9.3 kB)
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# ...
#   Using cached altair-5.0.1-py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached antiorm-1.2.1.tar.gz (171 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached anyio-3.7.0-py3-none-any.whl.metadata (4.7 kB)
# ...

# %%
# ! python3 main_gradio.py --resume ./results/omni/model_best.ckpt
# Out:
# 'python3' is not recognized as an internal or external command,
# operable program or batch file.

# %%
! pip install gradio

# %%
! pip install nvidia-pyindex
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for nvidia-pyindex: filename=nvidia_pyindex-1.0.9-py3-none-any.whl size=8430 sha256=9d88195de8435b8a4e424989732c911ec168899eaa4ae04969e67fb1ed4b262b
#   Stored in directory: c:\users\suditi\appdata\local\pip\cache\wheels\49\d0\7d\b68b3665d16ee20355e65fb7ef48b7ca26533217d9f09924fe
# Successfully built nvidia-pyindex
# ...

# %%
! pip install nvidia-nccl-cu116
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [17 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\Suditi\AppData\Local\Temp\pip-install-xa5ttmgg\nvidia-nccl-cu116_db55cc5295f34e539ca6ff8d4c5a4e10\setup.py", line 152, in <module>
#           raise RuntimeError(open("ERROR.txt", "r").read())
#       RuntimeError:
#       ###########################################################################################
#       The package you are trying to install is only a placeholder project on PyPI.org repository.
#       This package is hosted on NVIDIA Python Package Index.
#
# ...

# %%
! python3 main_gradio.py --resume ./results/omni/model_best.ckpt
# Out:
# 'python3' is not recognized as an internal or external command,
# operable program or batch file.
